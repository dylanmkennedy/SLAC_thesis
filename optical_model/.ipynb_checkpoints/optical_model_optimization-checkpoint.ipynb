# %%
import numpy as np
from matplotlib import pyplot as plt
from optical_model_discrete import optical_model

# %%
#construct the optical model by passing it the matched quad settings (as a
#1d vector with 16 vals, 1 val for each LTU quad) and the beam energy in MeV

#the values in this cell are taken from an aggregation of 3 real scans performed during an MD on 2018-12-18 from 10:12am - 10:25am


gdet_max = 3.130072548518238 #the highest seen gas detector reading

#the LTU quad settings that produced the highest gdet reading (above). We assume the beam was matched at these settings.
matched_quad_settings = np.array([-80.14843195,  73.91221362, -86.55598278,   0.1345117 , 
                                   57.26686987,  21.0890534 , -21.06755655,  21.10042229,
                                  -21.1006412 ,  21.07691109, -21.05064652,  50.2967137 ,
                                  -60.7843127 ,  17.9053793 ,  50.7211199 , -15.        ])


beamEnergyMeV = 14535.0 #beam energy in MeV

#construct model
model = optical_model(matched_quad_settings, beamEnergyMeV, gdet_max)
# model = optimized_model

# %%
#collect settings for a 1d scan of the first LTU quad (QUAD:LTU1:620) (index 0)
quad_id = 0
scan = np.array([np.copy(model.matched_quad_settings) for i in range(1000)])
xs = np.linspace(.8, 1.2, 1000)*model.matched_quad_settings[quad_id]
scan[:,quad_id] = xs

beamsizes = [] #container for beamsize results
gdets = [] #container for gas detector results

#evaluate beamsize and simulated gdet (gas detector) for each setting in the scan
for setting in scan:
    model.update_settings(setting) #update model to new quad settings
    gdet, beamsize =  model.gas_detector()
    beamsizes += [beamsize] #evaluate beamsize at current settings
    gdets += [gdet] #evaluate "gdet" at current settings

# %%
#plot the modeled beamsizes vs the quad values (1d scan)
plt.plot(xs, beamsizes)
plt.xlabel('QUAD:LTU1:620 Field Integral (kG)')
plt.ylabel('<Beamsize> (micrometers)')
plt.title('<Beamsize> vs. QUAD:LTU1:620')
# Out:
# Text(0.5, 1.0, '<Beamsize> vs. QUAD:LTU1:620')

# %%
#plot the "simulated" gas detector readings vs the quad values (1d scan)
plt.plot(xs, gdets)
plt.xlabel('QUAD:LTU1:620 Field Integral (kG)')
plt.ylabel('GDET (Simulated)')
plt.title('GDET (Simulated) vs. QUAD:LTU1:620')
# Out:
# Text(0.5, 1.0, 'GDET (Simulated) vs. QUAD:LTU1:620')

# %%
#perform a 2d raster scan by varying the quads at index 0 and 1 (QUAD:LTU1:620 and QUAD:LTU1:640)

quadx_id = 0 #QUAD:LTU1:620
quady_id = 1 #QUAD:LTU1:640
num_points = 99 #heatmap will be num_points x num_points
scan_range = 5 #quad values in scan will range from matched_quad_setting +/- scan_range

xs = np.linspace(-scan_range, scan_range, num_points) + model.matched_quad_settings[quadx_id]
ys = np.linspace(-scan_range, scan_range, num_points) + model.matched_quad_settings[quady_id]

beamsizes = np.zeros((num_points,num_points)) #container for beamsize results
gdets = np.zeros((num_points,num_points)) #container for gas detector results

#evaluate beamsize and simulated gdet (gas detector) for each setting in the scan
for i, x in enumerate(xs):
    for j, y in enumerate(ys):
        setting = np.copy(model.matched_quad_settings)
        setting[quadx_id] = x
        setting[quady_id] = y
        model.update_settings(setting)
        gdet, beamsize =  model.gas_detector()
        gdets[-(j+1),i] = gdet
        beamsizes[-(j+1),i] =  beamsize

# %%
#plot a heatmap of the results of the 2d raster scan of beamsize

plt.imshow(beamsizes, cmap = 'inferno', interpolation='none')


step_x = int(num_points / 2)
x_positions = np.arange(0,num_points,step_x) 
x_labels = np.round(xs[::step_x],1) 
plt.xticks(x_positions, x_labels)
plt.xlabel('QUAD:LTU1:620 Field Integral (kG)')

step_y = int(num_points / 2)
y_positions = np.arange(0,num_points,step_y)[::-1]
y_labels = np.round(ys[::step_y],1)
plt.yticks(y_positions, y_labels)
plt.ylabel('QUAD:LTU1:640 Field Integral (kG)')

cbar = plt.colorbar()
cbar.set_label('<Beamsize> (micrometers)')
plt.title('<Beamsize> vs. quads')
plt.show()

# %%
#plot a heatmap of the results of the 2d raster scan of simulated Gas Detector

plt.imshow(gdets, cmap = 'inferno', interpolation='none')


step_x = int(num_points / 2)
x_positions = np.arange(0,num_points,step_x) 
x_labels = np.round(xs[::step_x],1) 
plt.xticks(x_positions, x_labels)
plt.xlabel('QUAD:LTU1:620 Field Integral (kG)')

step_y = int(num_points / 2)
y_positions = np.arange(0,num_points,step_y)[::-1]
y_labels = np.round(ys[::step_y],1)
plt.yticks(y_positions, y_labels)
plt.ylabel('QUAD:LTU1:640 Field Integral (kG)')

cbar = plt.colorbar()
cbar.set_label('GDET (simulated)')
plt.title('GDET (simulated) vs. quads')
plt.show()

# %%
#perform a 2d raster scan of the gas detector WITH NOISE vs. quads at index 0 and 1 (QUAD:LTU1:620 and QUAD:LTU1:640)



quadx_id = 0 #QUAD:LTU1:620
quady_id = 1 #QUAD:LTU1:640
num_points = 9 #heatmap will be num_points x num_points
scan_range = 5 #quad values in scan will range from matched_quad_setting +/- scan_range

xs = np.linspace(-scan_range, scan_range, num_points) + model.matched_quad_settings[quadx_id]
ys = np.linspace(-scan_range, scan_range, num_points) + model.matched_quad_settings[quady_id]

gdets = np.zeros((num_points,num_points)) #container for gas detector results

#evaluate beamsize and simulated gdet (gas detector) for each setting in the scan
for i, x in enumerate(xs):
    for j, y in enumerate(ys):
        setting = np.copy(model.matched_quad_settings)
        setting[quadx_id] = x
        setting[quady_id] = y
        model.update_settings(setting)
        
        #calculate gas detector plus gaussian noise from signal and from background.
        #uses default arguments: snr = signal-to-noise ratio, bg_std_dev = std dev of background noise
        gdet =  model.gas_detector_with_noise(snr = 0.05, bg_std_dev = 0.1)
        
        
        gdets[-(j+1),i] = gdet #fill 2d heatmap array

# %%
#plot a heatmap of the results of the 2d raster scan of simulated Gas Detector

plt.imshow(gdets, cmap = 'inferno', interpolation='none')


step_x = int(num_points / 2)
x_positions = np.arange(0,num_points,step_x) 
x_labels = np.round(xs[::step_x],1) 
plt.xticks(x_positions, x_labels)
plt.xlabel('QUAD:LTU1:620 Field Integral (kG)')

step_y = int(num_points / 2)
y_positions = np.arange(0,num_points,step_y)[::-1]
y_labels = np.round(ys[::step_y],1)
plt.yticks(y_positions, y_labels)
plt.ylabel('QUAD:LTU1:640 Field Integral (kG)')

cbar = plt.colorbar()
cbar.set_label('GDET (simulated)')
plt.title('GDET (simulated) vs. quads')
plt.show()

# %%
xs_meas = np.array([[-71.29517663,  82.12737345, -86.62848673,  48.081103  ],
       [-71.24880416,  82.9842705 , -86.59907349,  48.05179283],
       [-72.79547332,  81.80676254, -88.73175232,  46.28353596],
       [-73.53790569,  79.47660056, -87.71859726,  49.89015171],
       [-75.02804426,  77.2569422 , -86.20062915,  49.65512194],
       [-76.4557759 ,  75.10149356, -84.24740369,  48.93400895],
       [-77.66279139,  73.26250741, -82.34903901,  48.0727937 ],
       [-77.30018076,  73.66572379, -83.94186642,  49.38928865],
       [-77.49101346,  73.70676331, -84.0516922 ,  50.7031917 ],
       [-77.55341475,  72.07032932, -85.5446089 ,  48.87604281],
       [-77.8046632 ,  70.80930258, -86.82277727,  48.47842568],
       [-77.91296036,  74.44288522, -83.71793528,  45.95400073],
       [-76.23827977,  69.77628887, -86.86283045,  51.7980849 ],
       [-79.14021977,  72.7390678 , -86.18291896,  53.10164831],
       [-78.81599582,  73.20239576, -86.58758138,  53.19725436],
       [-79.6710566 ,  72.80836411, -85.83956682,  53.71525317],
       [-79.84030573,  73.00810575, -85.92568651,  54.34482778],
       [-80.14843195,  73.91221362, -86.55598278,  57.26686987],
       [-81.32063607,  74.11169427, -85.93876007,  55.76259684],
       [-78.25034289,  71.68188749, -85.91921004,  54.34508254],
       [-79.21798809,  73.43302239, -86.47315502,  54.88002578],
       [-81.11435956,  71.17581308, -84.59236224,  55.84579875],
       [-79.666429  ,  72.30556213, -85.73668536,  54.28287696],
       [-82.79726582,  75.97088468, -83.79696228,  57.26686987],
       [-78.09461098,  70.04532682, -87.36484098,  57.26686987],
       [-82.79726582,  75.97088468, -85.61979124,  54.37688194],
       [-79.83481748,  72.26973523, -86.48228109,  55.16818841],
       [-71.21026779,  82.12737345, -86.62848673,  48.081103  ],
       [-70.52996036,  82.21015959, -86.71702464,  47.25996736],
       [-71.82435052,  83.5003859 , -87.47913209,  50.45524206],
       [-68.52296422,  79.18800182, -84.0463421 ,  48.39852903],
       [-72.5337246 ,  85.09015238, -89.56080357,  45.24285671],
       [-73.01816537,  85.09015238, -83.70255409,  46.65063051],
       [-68.25330771,  79.16459452, -89.56080357,  47.47680892],
       [-65.29634763,  82.12737345, -88.87000241,  47.17361677],
       [-71.21026779,  76.20181558, -88.91212672,  46.00612102],
       [-74.16722788,  75.50769528, -89.0293706 ,  47.16830095],
       [-72.37072279,  75.20333107, -88.07677058,  43.61522613],
       [-71.98194347,  73.60439069, -90.01769134,  43.35579803],
       [-72.85030011,  75.18046398, -85.64994554,  44.15338931],
       [-73.72072999,  73.36436817, -82.98573789,  44.19430306],
       [-74.13418962,  75.28047259, -83.19180952,  44.11274521],
       [-71.98605633,  71.81273996, -84.2882535 ,  44.67205053],
       [-70.9966821 ,  71.83067984, -83.99684951,  44.115638  ],
       [-73.91810943,  70.2922448 , -84.77801945,  46.21848526],
       [-74.45227481,  68.98083247, -85.03453309,  46.20142335],
       [-74.95698539,  67.18744854, -85.58140705,  45.39805381],
       [-74.67636068,  66.4880532 , -84.64631527,  48.25587834],
       [-75.66797542,  68.85344377, -85.07438216,  46.53759294],
       [-74.97553609,  68.84822952, -85.593509  ,  46.63687941],
       [-75.21223293,  68.74149576, -84.90038584,  46.45074713],
       [-75.4021682 ,  69.48108304, -85.26694345,  46.01472223],
       [-75.28815298,  69.33311051, -85.26554646,  46.12872194],
       [-75.25529568,  69.15110976, -85.21433104,  46.27440766],
       [-76.63677979,  69.41387695, -84.75575817,  46.10521358],
       [-73.47695504,  68.6487171 , -85.75813184,  46.58280135],
       [-70.51999496,  67.94500667, -87.05261066,  47.13780767],
       [-72.86181807,  68.52923574, -85.97718719,  46.61348561],
       [-73.64824502,  68.58146676, -85.70740353,  46.84747837],
       [-71.29514533,  68.22273065, -87.25188133,  49.76952045],
       [-71.62936422,  67.95508272, -85.89994556,  48.21936831],
       [-72.74208413,  67.63959582, -88.63972037,  49.16676255],
       [-70.69128494,  70.30492848, -88.45357254,  49.24467459],
       [-73.21896775,  68.75741146, -86.66611115,  47.91114345],
       [-73.22041736,  68.77775895, -86.68111237,  47.94191431],
       [-73.21719656,  68.75833404, -86.70001698,  48.02836095],
       [-73.44695286,  68.5390416 , -86.23391054,  46.9676271 ],
       [-74.84495893,  68.80474479, -86.58625793,  49.76952045],
       [-73.47582092,  68.61707675, -87.11502146,  49.76952045],
       [-72.93181198,  69.72409373, -88.59741717,  52.69156254],
       [-73.13482034,  68.17424112, -87.66037096,  51.63954477],
       [-71.21026779,  82.12737345, -86.62848673,  48.081103  ],
       [-70.52996036,  82.21015959, -86.71702464,  47.25996736],
       [-70.64761368,  80.32505487, -86.82730931,  50.8761119 ],
       [-71.63676975,  85.01526659, -83.70284251,  49.480912  ],
       [-68.25330771,  79.16459452, -89.56080357,  47.71938593],
       [-74.12088095,  79.16459452, -89.56080357,  47.70069702],
       [-70.06514199,  84.25703205, -89.56080357,  49.088729  ],
       [-68.25330771,  79.16459452, -85.44676726,  45.15906092],
       [-70.97985073,  80.18627131, -89.56080357,  45.15906092],
       [-74.16722788,  79.16459452, -85.94093756,  45.15906092],
       [-77.12418796,  78.05801209, -84.4025526 ,  43.58087659],
       [-77.86125214,  80.00549127, -84.63997993,  42.53624516],
       [-77.34985062,  75.09523316, -83.02859213,  45.09964168],
       [-77.57219582,  72.90586056, -82.16065292,  46.13935757],
       [-77.67154402,  74.04445075, -81.61774058,  46.44379879],
       [-76.71618571,  71.49004711, -83.15665256,  45.14622434],
       [-75.60624819,  70.94277549, -82.64526228,  44.46452843],
       [-76.1769812 ,  70.42258103, -84.48973415,  45.26853829],
       [-76.69385536,  69.88689285, -84.64018944,  44.90637027],
       [-76.52785573,  69.47520388, -84.41881172,  45.26694564],
       [-76.27740197,  70.44987472, -85.05589299,  44.43364449],
       [-78.55134628,  70.60940913, -85.77856219,  45.90685671],
       [-76.06381824,  68.9664973 , -84.18537224,  44.23969891],
       [-75.81316882,  69.43440184, -84.24280404,  44.62012494],
       [-72.85620874,  68.03169769, -84.64223897,  44.71559261],
       [-74.03568488,  69.0049877 , -84.28533598,  44.57404665],
       [-72.85620874,  66.47162291, -85.73438335,  45.08730551],
       [-72.86704796,  67.2349652 , -84.30576324,  45.12701887],
       [-71.9489421 ,  67.64912545, -85.33132569,  44.56753443],
       [-74.14208636,  68.43540103, -85.06387908,  44.84259167],
       [-73.95648788,  68.07900237, -84.53586907,  44.26650216],
       [-72.85620874,  68.83391143, -84.75438923,  45.32365094],
       [-75.22924867,  69.48056823, -84.22669757,  44.60779556],
       [-78.7701289 ,  70.20358479, -83.09632353,  44.0697659 ],
       [-74.84270837,  68.85397481, -84.47730125,  44.72181022],
       [-72.07674761,  68.65056817, -84.2280184 ,  45.0562101 ],
       [-72.85620874,  67.89043726, -85.43532664,  45.31743537],
       [-73.8175569 ,  68.47548948, -84.66634318,  44.75020376],
       [-73.7164844 ,  68.38468668, -84.86479055,  44.8063519 ],
       [-73.73575375,  68.38673107, -84.64989499,  44.74002119],
       [-73.68294609,  68.4058972 , -84.63975272,  44.74716322],
       [-75.34744986,  69.43391034, -84.15117141,  44.68650473],
       [-75.44867716,  69.36489266, -83.96661052,  44.7451169 ]])

# %%
ys_meas = np.array([0.36298513, 0.33227659, 0.3065018 , 0.25638317, 0.69761294,
       1.24524383, 1.94890224, 1.94353414, 2.21259848, 2.0431101 ,
       2.77070051, 1.79506533, 2.53551117, 2.83939465, 2.97733448,
       2.9212596 , 3.01146566, 3.13007255, 2.67621956, 2.95614199,
       2.93722192, 2.8063598 , 2.32956639, 2.92773321, 1.6686436 ,
       2.98111492, 2.68829856, 0.32083942, 0.35907643, 0.34706639,
       0.23228615, 0.08804107, 0.08299295, 0.15493497, 0.39428737,
       0.054486  , 0.74897185, 0.61267486, 0.85067617, 0.55320365,
       1.4997701 , 1.71951396, 1.54941376, 1.94657681, 1.57975555,
       2.49613457, 2.69643438, 2.21631718, 2.2115581 , 2.69085162,
       2.66922293, 2.6587559 , 2.69923374, 2.66338161, 2.58269479,
       2.67107139, 2.72130866, 2.4828319 , 2.61892524, 2.82427748,
       2.56047349, 2.26052765, 2.28850547, 2.39934816, 2.77537897,
       2.78223325, 2.65268201, 2.60334196, 2.6931341 , 2.95951378,
       2.77736619, 0.37200896, 0.34704301, 0.30731522, 0.2753945 ,
       0.0366625 , 0.33212973, 0.29377212, 0.18844159, 0.23526218,
       0.33435826, 0.77729107, 1.08483327, 0.58755327, 1.93292671,
       2.12096212, 1.90467345, 2.42782154, 2.30204303, 2.55254515,
       2.56329169, 2.49896215, 2.44175063, 1.58710975, 2.59959987,
       2.75382947, 2.70925357, 2.63858606, 2.5004581 , 2.48197482,
       2.53129826, 2.60274136, 2.53812876, 2.55971147, 2.50451941,
       2.21308088, 2.55355508, 2.31477997, 2.51614219, 2.76020901,
       2.54526235, 2.60768234, 2.56834161, 2.70167937])

# %%
# xs_meas = np.array([[-71.2945408 ,  82.12800592, -86.62818989,  48.08120685],
#        [-71.2945408 ,  82.12800592, -86.62818989,  48.08120685],
#        [-71.29450362,  82.12794058, -86.62824104,  48.08122258],
#        [-65.41146417,  82.12853429, -86.62790937,  48.08126443],
#        [-71.2951007 ,  80.25487084, -86.62787169,  48.08135337],
#        [-71.29420086,  76.08945663, -81.94656068,  48.08138638],
#        [-71.29411672,  82.12864829, -86.63249879,  43.72203513],
#        [-76.03786112,  78.96256392, -84.26572977,  45.90282623],
#        [-83.0601122 ,  77.38088088, -83.116846  ,  44.8130609 ],
#        [-77.17482425,  76.59087239, -89.56381379,  44.26826227],
#        [-72.76306069,  80.74621694, -83.98829068,  47.12805526],
#        [-77.43129329,  85.26330344, -83.48292116,  43.78726434],
#        [-76.25721992,  84.04766625, -84.26912742,  44.86408772],
#        [-78.18765659,  81.57923671, -86.47275149,  43.61275734],
#        [-74.11941271,  80.94589304, -84.5045013 ,  46.24928356],
#        [-80.35139326,  79.59916188, -82.63161969,  41.74149432],
#        [-85.95976488,  78.33488245, -80.63299746,  45.1117792 ],
#        [-93.19919734,  76.43471598, -77.63591352,  45.80563433],
#        [-89.05157314,  78.20559505, -80.82081964,  42.01684411],
#        [-86.09288869,  78.85855456, -81.78908347,  46.66152889],
#        [-95.23511475,  74.17506701, -78.91042775,  44.43574641],
#        [-94.16825206,  74.67370255, -81.40443791,  48.49322932],
#        [-86.41433634,  77.20848693, -80.96677011,  43.63541882],
#        [-87.07372774,  76.38661415, -81.25848475,  46.8741436 ],
#        [-86.41530251,  75.78177135, -81.40388131,  48.49345292],
#        [-89.53628052,  73.58883048, -80.24399241,  44.76735818],
#        [-95.81340752,  73.16824419, -77.47902083,  46.5915082 ],
#        [-90.11160294,  74.28101855, -81.70953749,  45.25784538],
#        [-86.18725855,  77.05833717, -81.01858634,  46.80221323],
#        [-91.11988579,  74.58790741, -80.15732316,  46.46491466],
#        [-87.97536839,  74.68520153, -80.82399902,  46.63024452],
#        [-84.73693685,  76.58237248, -82.26095591,  46.65288448],
#        [-81.53701077,  77.46454886, -82.59665358,  47.82440913],
#        [-83.93317481,  76.74592198, -81.9866413 ,  47.4849479 ],
#        [-87.51846607,  75.55307164, -80.35565196,  48.0522147 ],
#        [-85.43193374,  76.32486189, -81.78482123,  47.00262444],
#        [-89.07248685,  75.17924928, -80.52885574,  46.97985782],
#        [-85.57276742,  77.48703115, -81.54396678,  48.00824692],
#        [-87.37614829,  75.38533588, -81.00415272,  46.9749064 ],
#        [-87.96030124,  74.27713191, -81.3420014 ,  47.92310234],
#        [-86.63067882,  76.36284253, -81.09915146,  47.08254455],
#        [-83.85479591,  76.74823391, -82.11735717,  47.79682516],
#        [-87.767933  ,  75.57134893, -80.92625577,  47.18393789],
#        [-86.03098438,  76.3439164 , -81.4419242 ,  47.04268214],
#        [-86.4037233 ,  75.85543554, -81.39433661,  46.98862683],
#        [-85.92373186,  76.0528575 , -81.59454615,  47.74817868],
#        [-87.25194175,  75.7520525 , -81.15693074,  46.9912433 ],
#        [-86.63636543,  76.08469421, -81.2941781 ,  46.26471454],
#        [-86.4582183 ,  76.07693591, -81.36902027,  46.63544775],
#        [-86.3420007 ,  76.03856752, -81.47071801,  46.99723019],
#        [-85.73181073,  76.3339831 , -81.61289071,  47.02260485],
#        [-85.91792846,  76.09015566, -81.58973529,  46.99607281],
#        [-71.20964664,  82.12805194, -86.62813432,  48.08117328],
#        [-71.20964664,  82.12805194, -86.62813432,  48.08117328],
#        [-71.20917234,  82.12853938, -86.62788802,  48.081294  ],
#        [-77.09149697,  82.12860134, -86.62774457,  48.0813787 ],
#        [-71.20871821,  75.79974039, -86.62777058,  48.08134147],
#        [-71.20894667,  82.12882522, -81.94648169,  48.0813819 ],
#        [-71.20909019,  82.1286502 , -86.21208393,  52.43914402],
#        [-74.15025915,  78.96461897, -91.30910478,  50.25999691],
#        [-75.62069247,  77.38243972, -88.96817582,  44.81262209],
#        [-73.41485831,  79.75565509, -84.89458557,  44.26834433],
#        [-70.84121464,  82.52436469, -82.53191588,  49.44343821],
#        [-74.42620978,  78.6673391 , -87.35947164,  45.97041762],
#        [-76.86169764,  76.04724892, -85.23755675,  45.1194164 ],
#        [-79.68770566,  73.00677697, -84.54313543,  43.63837505],
#        [-70.8632324 ,  73.0068115 , -84.54327547,  43.63844513],
#        [-67.75089582,  68.44594439, -83.50107507,  41.41681937],
#        [-70.19256009,  71.35672214, -81.88246838,  43.47268458],
#        [-69.591957  ,  66.06937881, -85.50818467,  44.77676284],
#        [-67.68051942,  59.22634302, -86.70328189,  45.03100634],
#        [-70.98932768,  65.15993604, -81.43645027,  39.31122903],
#        [-72.40435686,  66.50443668, -85.95961353,  41.83994836],
#        [-63.50702572,  57.04227104, -82.96339818,  38.55308538],
#        [-73.52377191,  69.81515971, -84.67019952,  43.47816151],
#        [-75.50392652,  66.06856068, -85.28609642,  43.28591745],
#        [-69.68906549,  67.85173696, -83.94735435,  41.88425803],
#        [-69.49205395,  68.68420122, -81.82136869,  42.88557665],
#        [-71.67652559,  67.04936647, -84.92497477,  42.10115986],
#        [-71.25098858,  70.97409087, -88.09013151,  46.80860291],
#        [-67.58131526,  64.67566416, -86.56390178,  44.30736252],
#        [-69.06673115,  66.33106769, -86.0903351 ,  44.10004612],
#        [-71.10414566,  67.36036495, -88.35857148,  47.00932266],
#        [-71.95715908,  69.78795618, -88.22272454,  45.2325688 ],
#        [-70.18330969,  66.99912064, -86.18653448,  44.89091983],
#        [-69.76431961,  62.89608876, -84.69216474,  42.24177826],
#        [-70.87946644,  68.95446034, -87.23897811,  45.66708725],
#        [-72.85497376,  68.85057548, -87.26365349,  45.73389078]])
# ys_meas = np.array([0.35238339, 0.01746984, 0.1893754 , 0.09893695, 0.43239698,
#        0.96529476, 1.30014642, 0.05878928, 0.21364243, 0.26797682,
#        0.63350355, 0.24555427, 0.38109819, 0.53045656, 1.95976325,
#        1.22707512, 0.62582604, 0.92413996, 1.21505288, 0.5564143 ,
#        0.84295261, 2.18506985, 2.75207541, 1.70135775, 0.77299061,
#        0.53636003, 2.5365024 , 1.58708324, 2.25502795, 2.26548378,
#        2.18408123, 2.41835367, 2.26779466, 2.77687224, 2.64321491,
#        2.17753828, 2.77170911, 2.61401826, 2.75921604, 2.54043288,
#        2.36031639, 2.75983426, 2.73311305, 2.67576447, 2.74349446,
#        2.65272695, 2.66386866, 2.69806246, 2.71887745, 2.77000819,
#        2.69552316, 2.67643933, 0.37870062, 0.48460384, 0.96370364,
#        0.06777458, 0.12527089, 0.20086069, 0.21307045, 0.82669649,
#        0.00793244, 0.73069231, 1.25776968, 1.24380914, 1.36760652,
#        1.4828721 , 1.08473565, 2.15357739, 1.25979143, 1.8067049 ,
#        1.78134564, 0.67377448, 1.9949257 , 1.42646731, 2.13831341,
#        1.34451619, 2.37126018, 2.15438523, 2.04690118, 2.1853262 ,
#        2.35951907, 1.98109232, 2.44784854, 1.9246709 , 2.43056996,
#        2.18035654, 2.42401772, 2.33777826])

# %%
def model_err(matched_x4d):
    matched_settings = np.copy(matched_quad_settings)
    matched_settings[0:3] = matched_x4d[0:3]
    matched_settings[4] = matched_x4d[3]
    model = optical_model(matched_settings, beamEnergyMeV, gdet_max)
    model.gdet_max = matched_x4d[4]
    gdets = []
    for x in xs_meas:
        model.update_settings4d(x)
        gdet = model.gas_detector()[0]
        gdets += [gdet]
    tot_sq_err = np.sum((ys_meas-gdets)**2.)

    return tot_sq_err

# %%
from scipy.optimize import fmin
x_guess = np.array([-80.14843195,  73.91221362, -86.55598278, 57.26686987])
x_guess = np.append(x_guess, [gdet_max])
xopt = fmin(model_err, x_guess)
# Out:
# Optimization terminated successfully.
#          Current function value: 23.650995
#          Iterations: 318
#          Function evaluations: 530

# %%
print('Initial quad settings: ', x_guess[:-1])
print('Initial guess of max Gas Detector: ', x_guess[-1])

print('Optimized quad settings: ', xopt[:-1])
print('Optimized guess of max Gas Detector: ', xopt[-1])
# Out:
# Initial quad settings:  [-80.14843195  73.91221362 -86.55598278  57.26686987]
# Initial guess of max Gas Detector:  3.130072548518238
# Optimized quad settings:  [-103.66308225   80.53927584  -87.10535327   68.56143218]
# Optimized guess of max Gas Detector:  5.189253103629984

# %%
optimized_matched_settings = np.copy(matched_quad_settings)
optimized_matched_settings[0:3] = xopt[0:3]
optimized_matched_settings[4] = xopt[3]
optimized_gdet_max = xopt[4]
optimized_model = optical_model(optimized_matched_settings, beamEnergyMeV, optimized_gdet_max)

# %%
gdets = []
gdets_init = []
for x in xs_meas:
    optimized_model.update_settings4d(x)
    gdet = optimized_model.gas_detector()[0]
    model.update_settings4d(x)
    gdet_init = model.gas_detector()[0]
    gdets += [gdet]
    gdets_init += [gdet_init]
tot_sq_err = np.sum((ys_meas-gdets)**2.)
tot_sq_err_init = np.sum((ys_meas-gdets_init)**2.)
fig, (ax1, ax2) = plt.subplots(1,2,sharey=True)
ax1.scatter(ys_meas,gdets_init, c='m')
ax2.scatter(ys_meas,gdets)
ax1.set(title='Before Optimization')
ax2.set(title='After Optimization')

handle = ax1.plot([0,3],[0,3], c='r')
ax1.legend(handle, ['perfect prediction'])
ax1.set(xlabel='Measured Gas Detector')
ax1.set(ylabel='Predicted Gas Detector')
ax2.set(xlabel='Measured Gas Detector')
handle = ax2.plot([0,3],[0,3], c='r')
ax2.legend(handle, ['perfect prediction'])
plt.tight_layout()

print('initial error: ', tot_sq_err_init)
print('final error: ', tot_sq_err)
plt.show()
# Out:
# initial error:  125.62783589134364
# final error:  23.65099481364967

# %%
# plt.scatter(xs_meas[:,0], gdets_init, c='g')
plt.scatter(xs_meas[:,0], gdets)
plt.scatter(xs_meas[:,0], ys_meas, c = 'r')
plt.legend(['predicted', 'measured'])
plt.title('Gas Detector (measured/predicted) vs. QUAD:LTU1:620')
plt.xlabel('QUAD:LTU1:620 Field Integral (kG)')
plt.ylabel('Gas Detector (measured/predicted)')
plt.show()

# %%
# plt.scatter(xs_meas[:,1], gdets_init, c='g')
plt.scatter(xs_meas[:,1], gdets)
plt.scatter(xs_meas[:,1], ys_meas, c = 'r')
plt.legend(['predicted', 'measured'])
plt.title('Gas Detector (measured/predicted) vs. QUAD:LTU1:640')
plt.xlabel('QUAD:LTU1:640 Field Integral (kG)')
plt.ylabel('Gas Detector (measured/predicted)')
plt.show()

# %%
# plt.scatter(xs_meas[:,2], gdets_init, c='g')
plt.scatter(xs_meas[:,2], gdets)
plt.scatter(xs_meas[:,2], ys_meas, c = 'r')
plt.legend(['predicted', 'measured'])
plt.title('Gas Detector (measured/predicted) vs. QUAD:LTU1:660')
plt.xlabel('QUAD:LTU1:660 Field Integral (kG)')
plt.ylabel('Gas Detector (measured/predicted)')
plt.show()

# %%
# plt.scatter(xs_meas[:,3], gdets_init, c='g')
plt.scatter(xs_meas[:,3], gdets)
plt.scatter(xs_meas[:,3], ys_meas, c = 'r')
plt.legend(['predicted', 'measured'])
plt.title('Gas Detector (measured/predicted) vs. QUAD:LTU1:680')
plt.xlabel('QUAD:LTU1:680 Field Integral (kG)')
plt.ylabel('Gas Detector (measured/predicted)')
plt.show()

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1,3,sharey=True)
ax1.scatter(xs_meas[:,0],gdets_init, c='m')
ax2.scatter(xs_meas[:,0],gdets)
ax3.scatter(xs_meas[:,0],ys_meas, c='r')
ax1.set(title='Predicted GDET (Before Optimization)')
ax2.set(title='Predicted GDET (After Optimization)')
ax3.set(title='Measured GDET')
ax1.set(xlabel='QUAD:LTU1:620 Field Integral (kG)')
ax2.set(xlabel='QUAD:LTU1:620 Field Integral (kG)')
ax3.set(xlabel='QUAD:LTU1:620 Field Integral (kG)')
ax1.set(ylabel='Gas Detector')

fig.set_figwidth(15)
plt.tight_layout()
plt.show()



fig, (ax1, ax2, ax3) = plt.subplots(1,3,sharey=True)
ax1.scatter(xs_meas[:,1],gdets_init, c='m')
ax2.scatter(xs_meas[:,1],gdets)
ax3.scatter(xs_meas[:,1],ys_meas, c='r')
ax1.set(title='Predicted GDET (Before Optimization)')
ax2.set(title='Predicted GDET (After Optimization)')
ax3.set(title='Measured GDET')
ax1.set(xlabel='QUAD:LTU1:640 Field Integral (kG)')
ax2.set(xlabel='QUAD:LTU1:640 Field Integral (kG)')
ax3.set(xlabel='QUAD:LTU1:640 Field Integral (kG)')
ax1.set(ylabel='Gas Detector')

fig.set_figwidth(15)
plt.tight_layout()
plt.show()

fig, (ax1, ax2, ax3) = plt.subplots(1,3,sharey=True)
ax1.scatter(xs_meas[:,2],gdets_init, c='m')
ax2.scatter(xs_meas[:,2],gdets)
ax3.scatter(xs_meas[:,2],ys_meas, c='r')
ax1.set(title='Predicted GDET (Before Optimization)')
ax2.set(title='Predicted GDET (After Optimization)')
ax3.set(title='Measured GDET')
ax1.set(xlabel='QUAD:LTU1:660 Field Integral (kG)')
ax2.set(xlabel='QUAD:LTU1:660 Field Integral (kG)')
ax3.set(xlabel='QUAD:LTU1:660 Field Integral (kG)')
ax1.set(ylabel='Gas Detector')

fig.set_figwidth(15)
plt.tight_layout()
plt.show()

fig, (ax1, ax2, ax3) = plt.subplots(1,3,sharey=True)
ax1.scatter(xs_meas[:,3],gdets_init, c='m')
ax2.scatter(xs_meas[:,3],gdets)
ax3.scatter(xs_meas[:,3],ys_meas, c='r')
ax1.set(title='Predicted GDET (Before Optimization)')
ax2.set(title='Predicted GDET (After Optimization)')
ax3.set(title='Measured GDET')
ax1.set(xlabel='QUAD:LTU1:680 Field Integral (kG)')
ax2.set(xlabel='QUAD:LTU1:680 Field Integral (kG)')
ax3.set(xlabel='QUAD:LTU1:680 Field Integral (kG)')
ax1.set(ylabel='Gas Detector')

fig.set_figwidth(15)
plt.tight_layout()
plt.show()

# %%
def model_err_twiss(twiss):
    model = optical_model(matched_quad_settings, beamEnergyMeV, optimized_gdet_max)
    model.txi = twiss[:2]
    model.tyi = twiss[2:4]
    gdets = []
    for x in xs_meas:
        model.update_settings4d(x)
        gdet = model.gas_detector()[0]
        gdets += [gdet]
    tot_sq_err = np.sum((ys_meas-gdets)**2.)

    return tot_sq_err

# %%
from scipy.optimize import fmin
twiss_guess = np.append(model.txi,model.tyi)
twiss_opt = fmin(model_err_twiss, twiss_guess)
# Out:
# Optimization terminated successfully.
#          Current function value: 23.650995
#          Iterations: 213
#          Function evaluations: 355

# %%
print('Initial Twiss: ', twiss_guess)
print('Optimized Twiss: ', twiss_opt)
# Out:
# Initial Twiss:  [106.48510569   2.84662925 100.80959227   7.4835842 ]
# Optimized Twiss:  [ 52.10513124   0.80924197 128.92652823  11.20812479]

# %%
optimized_model_2 = optical_model(matched_quad_settings, beamEnergyMeV, optimized_gdet_max)
optimized_model_2.txi = twiss_opt[:2]
optimized_model_2.tyi = twiss_opt[2:4]

# %%
gdets = []
gdets_init = []
for x in xs_meas:
    optimized_model_2.update_settings4d(x)
    gdet = optimized_model_2.gas_detector()[0]
    model.update_settings4d(x)
    gdet_init = model.gas_detector()[0]
    gdets += [gdet]
    gdets_init += [gdet_init]
tot_sq_err = np.sum((ys_meas-gdets)**2.)
tot_sq_err_init = np.sum((ys_meas-gdets_init)**2.)
fig, (ax1, ax2) = plt.subplots(1,2,sharey=True)
ax1.scatter(ys_meas,gdets_init, c='m')
ax2.scatter(ys_meas,gdets)
ax1.set(title='Before Optimization')
ax2.set(title='After Optimization')

handle = ax1.plot([0,3],[0,3], c='r')
ax1.legend(handle, ['perfect prediction'])
ax1.set(xlabel='Measured Gas Detector')
ax1.set(ylabel='Predicted Gas Detector')
ax2.set(xlabel='Measured Gas Detector')
handle = ax2.plot([0,3],[0,3], c='r')
ax2.legend(handle, ['perfect prediction'])
plt.tight_layout()

print('initial error: ', tot_sq_err_init)
print('final error: ', tot_sq_err)
plt.show()
# Out:
# initial error:  125.62783589134364
# final error:  23.650994813606882
